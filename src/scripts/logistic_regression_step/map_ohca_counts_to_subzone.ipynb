# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from pathlib import Path
import os

# %%
CURRENT_DIRECTORY =  os.getcwd()
SRC_DIRECTORY = Path(CURRENT_DIRECTORY).parents[1]
print(SRC_DIRECTORY)

BASE_DATASET_PATH = Path(SRC_DIRECTORY).parents[0]
BASE_DATASET_PATH = BASE_DATASET_PATH / "datasets"
print(BASE_DATASET_PATH)
# Out:
# /Users/yitong/Desktop/Uni_Skool/Y3 Internship SingHealth/code/Mobile-AED-Study/src
# /Users/yitong/Desktop/Uni_Skool/Y3 Internship SingHealth/code/Mobile-AED-Study/datasets

# %%
subzones_filepath = Path(BASE_DATASET_PATH / f"3_OHCA_with_geometric_pts.gpkg")
ohca_points = gpd.read_file(subzones_filepath)

# %%
ohca_points
# Out:
#              Case #  Site # Date of Incident  Location of incident  \
# 0         SGSIN0213       2       2010-04-01              470146.0
# 1         SGSIN0218       2       2010-04-01              520926.0
# 2         SGSIN6480       6       2010-04-01              560565.0
# 3         SGSIN5332       5       2010-04-02              680626.0
# 4         SGSIN0214       2       2010-04-03              468963.0
# ...             ...     ...              ...                   ...
# 27724  SGSIN0223935       2       2016-06-17                   NaN
# 27725  SGSIN0625900       6       2016-08-31                   NaN
# 27726  SGSIN0127969       1       2016-10-03                   NaN
# 27727  SGSIN0526982       5       2016-10-09                   NaN
# 27728  SGSIN0227361       2       2016-10-26                   NaN
#
#       Location Unknown               Location Type  \
# 0                 None              Home Residence
# 1                 None              Home Residence
# 2                 None         Healthcare Facility
# 3                 None              Home Residence
# 4                 None         Place of Recreation
# ...                ...                         ...
# 27724              Yes    In EMS/Private ambulance
# 27725              Yes  Public/Commercial Building
# 27726              Yes              Street/Highway
# 27727              Yes              Street/Highway
# 27728              Yes              Street/Highway
#
#                Location Type Other Time call received at dispatch center  \
# 0                      HDB Level 7                              23:29:17
# 1                      HDB Level 2                              14:18:54
# 2              NKF Dialysis Centre                              16:35:03
# 3                      HDB Level 7                              02:28:08
# 4      East Coast Park NSC Carpark                              08:56:21
# ...                            ...                                   ...
# 27724                         None                              12:19:55
# 27725                         None                              14:50:33
# 27726                         None                              20:23:49
# 27727                         None                              12:24:47
# 27728                         None                              06:23:23
#
#       Estimated time of arrest       lat         lon  \
# 0                     23:35:00  1.334604  103.911889
# 1                     14:05:00  1.346122  103.940989
# 2                     16:30:00  1.369882  103.858475
# 3                     02:00:00  1.398315  103.745837
# 4                     09:00:00  1.315317  103.961890
# ...                        ...       ...         ...
# 27724                 12:44:00  1.304323  103.924755
# 27725                 14:40:00  1.310432  103.877204
# 27726                 20:44:00  1.323159  103.764190
# 27727                 12:20:00  1.297129  103.779480
# 27728                 06:15:00  1.338779  103.902021
#
#                           geometry
# 0      POINT (36744.065 35199.375)
# 1      POINT (39982.538 36473.112)
# 2      POINT (30799.605 39100.122)
# 3      POINT (18264.472 42244.265)
# 4      POINT (42308.771 33066.957)
# ...                            ...
# 27724  POINT (38175.996 31851.058)
# 27725  POINT (32884.001 32526.495)
# 27726  POINT (20306.656 33933.857)
# 27727  POINT (22008.275 31055.528)
# 27728  POINT (35645.836 35660.992)
#
# [27729 rows x 12 columns]
